# %%
from pymongo import MongoClient

# MongoDB 연결 설정
client = MongoClient('mongodb://localhost:27017/')
db = client['albums']

# for i in db.album.find({}, {'앨범': 1, '연도': 1}):
#     print(i)


# for i in db.album.find({'연도': '2000'}):
#     print(i)

# for i in db.album.find({'최고순위': {'$lte': 10}}):
#     print(i)

# for count in db.album.aggregate([{'$group': {'_id': "$연도", 'count': {'$sum': 1}}}]):
#     print(count)

# print(db.album.find().sort('연도', -1).limit(1)[0])

# print(db.album.find().sort('연도', 1).limit(1)[0])

# db.album.insert_one({'앨범': 'New Album', '연도': '2024', '최고순위': '1'})

# db.album.update_one({'앨범': 'New Album'}, {'$set': {'최고순위': '2'}})

# db.album.delete_one({'앨범': 'New Album'})
